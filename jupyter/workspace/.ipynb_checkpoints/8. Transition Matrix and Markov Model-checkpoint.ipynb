# %%
import pandas as pd
from matplotlib.pyplot import figure
from scipy.stats import entropy
import utils
import numpy as np

# %%
#----------------------------------------------------------------------------------------
#
#  1. Transition Matrix and Markov Model
#  (Explanation in Slides 42-43)
#
#----------------------------------------------------------------------------------------

# %%
#----------------------------------------------------------------------------------------
#Assumption: the AOIs are not overlapping
#----------------------------------------------------------------------------------------

# %%
#AOIs to consider --- **TO UPDATE IF YOU UPDATE THE AOIs**

#Coarse-grained level
#AoisToConsider = ['Text_Area','Figure', 'Formula']

#Fine-grained level
AoisToConsider = ['Paragraph1', 'Paragraph2', 'Paragraph3', 'Paragraph4',
       'Paragraph5', 'Paragraph6', 'SubFigure1',
       'SubFigure2', 'SubFigure3', 'Formula']

# %%
# Read dwell data using pandas library
data = pd.read_csv("data/dwells.csv")

# set display.max_columns to none, to show all the columns when using head()
pd.set_option('display.max_columns', None)

# %%
# Preview dwells data
data.head()
# Out:
#                   Respondent  VisitedAOI  Dwell Start  Dwell End  \
# 0  Anonymous 14-11-22 09h35m  Paragraph4     133.1086   433.0785
# 1  Anonymous 14-11-22 09h35m   Text_Area     133.1086   783.0360
# 2  Anonymous 14-11-22 09h35m  Paragraph1     566.4076   716.4244
# 3  Anonymous 14-11-22 09h35m  Paragraph1     899.6993  6957.3621
# 4  Anonymous 14-11-22 09h35m   Text_Area     899.6993  6957.3621
#
#    Number of Fixations in Dwell  Number of Saccades in Dwell  Dwell Time
# 0                           1.0                          1.0    299.9699
# 1                           2.0                          4.0    649.9274
# 2                           1.0                          0.0    150.0168
# 3                          23.0                         22.0   6057.6628
# 4                          23.0                         22.0   6057.6628

# %%
#----------------------------------------------------------------------------------------
#
# 1.1 Identify transitions (including self-transitions e.g., transitions from AOI1 to AOI1)
#
#----------------------------------------------------------------------------------------

# %%
transitions = pd.DataFrame()
transitions[['Respondent','TransitionSource','TransitionTarget']] = data.apply(lambda x: utils.identifyTransition(data,x.name), axis=1)

# %%
# Preview transitions dataframe
transitions.head()
# Out:
#                   Respondent TransitionSource TransitionTarget
# 0  Anonymous 14-11-22 09h35m       Paragraph4        Text_Area
# 1  Anonymous 14-11-22 09h35m        Text_Area       Paragraph1
# 2  Anonymous 14-11-22 09h35m       Paragraph1       Paragraph1
# 3  Anonymous 14-11-22 09h35m       Paragraph1        Text_Area
# 4  Anonymous 14-11-22 09h35m        Text_Area          Formula

# %%
# Generate transition matrix
transitionMatrix = utils.generateTransitionMatrix(transitions,'TransitionSource','TransitionTarget')

# %%
# Display transitionMatrix
display(transitionMatrix)
# Out:
# TransitionTarget  Paragraph4  Text_Area  Paragraph1  Formula  Paragraph3  \
# TransitionSource
# Paragraph4                 7          7           0        4           4
# Text_Area                  6          2          11        3          11
# Paragraph1                 0         10           6        0           4
# Formula                    1          3           1        4           0
# Paragraph3                 3          0           4        1           7
# Paragraph2                 6         14           5        1           1
# Figure                     2         15           0       10           0
# SubFigure2                 0          6           1        1           0
# SubFigure1                 1          7           0        6           0
# SubFigure3                 1          2           0        2           0
# Paragraph5                 6          5           1        1           4
# Paragraph6                 1         12           1        0           0
#
# TransitionTarget  Paragraph2  Figure  SubFigure2  SubFigure1  SubFigure3  \
# TransitionSource
# Paragraph4                 5       2           2           3           0
# Text_Area                 10       5           2           8           0
# Paragraph1                 7       1           0           0           0
# Formula                    4       6           1           9           2
# Paragraph3                 2       0           3           3           0
# Paragraph2                 3       2           1           0           0
# Figure                     0       3          26          17           7
# SubFigure2                 2      23          16          24          23
# SubFigure1                 0      31          20          12           3
# SubFigure3                 0       7          21           1           5
# Paragraph5                 0       5           8           0           0
# Paragraph6                 0       2           1           4           1
#
# TransitionTarget  Paragraph5  Paragraph6
# TransitionSource
# Paragraph4                 1           1
# Text_Area                 15           8
# Paragraph1                 2           0
# Formula                    1           1
# Paragraph3                 7           1
# Paragraph2                 0           0
# Figure                     0           7
# SubFigure2                 3           2
# SubFigure1                 1           0
# SubFigure3                 0           2
# Paragraph5                11           7
# Paragraph6                 7          32

# %%
# Export transitionMatrix as CSV
transitionMatrix.to_csv("data/transitionMatrix.csv")

# %%
#----------------------------------------------------------------------------------------
# Markov Model
#----------------------------------------------------------------------------------------

# %%
# Generate a transition matrix with values normalized over each row (by dividing all values by the sum of values in row)
transitionMatrixNormalized = utils.generateTransitionMatrix(transitions,'TransitionSource','TransitionTarget',normalize='index')

# %%
# Display transitionMatrixNormalized
display(transitionMatrixNormalized)
# Out:
# TransitionTarget  Paragraph4  Text_Area  Paragraph1   Formula  Paragraph3  \
# TransitionSource
# Paragraph4          0.194444   0.194444    0.000000  0.111111    0.111111
# Text_Area           0.074074   0.024691    0.135802  0.037037    0.135802
# Paragraph1          0.000000   0.333333    0.200000  0.000000    0.133333
# Formula             0.030303   0.090909    0.030303  0.121212    0.000000
# Paragraph3          0.096774   0.000000    0.129032  0.032258    0.225806
# Paragraph2          0.181818   0.424242    0.151515  0.030303    0.030303
# Figure              0.022989   0.172414    0.000000  0.114943    0.000000
# SubFigure2          0.000000   0.059406    0.009901  0.009901    0.000000
# SubFigure1          0.012346   0.086420    0.000000  0.074074    0.000000
# SubFigure3          0.024390   0.048780    0.000000  0.048780    0.000000
# Paragraph5          0.125000   0.104167    0.020833  0.020833    0.083333
# Paragraph6          0.016393   0.196721    0.016393  0.000000    0.000000
#
# TransitionTarget  Paragraph2    Figure  SubFigure2  SubFigure1  SubFigure3  \
# TransitionSource
# Paragraph4          0.138889  0.055556    0.055556    0.083333    0.000000
# Text_Area           0.123457  0.061728    0.024691    0.098765    0.000000
# Paragraph1          0.233333  0.033333    0.000000    0.000000    0.000000
# Formula             0.121212  0.181818    0.030303    0.272727    0.060606
# Paragraph3          0.064516  0.000000    0.096774    0.096774    0.000000
# Paragraph2          0.090909  0.060606    0.030303    0.000000    0.000000
# Figure              0.000000  0.034483    0.298851    0.195402    0.080460
# SubFigure2          0.019802  0.227723    0.158416    0.237624    0.227723
# SubFigure1          0.000000  0.382716    0.246914    0.148148    0.037037
# SubFigure3          0.000000  0.170732    0.512195    0.024390    0.121951
# Paragraph5          0.000000  0.104167    0.166667    0.000000    0.000000
# Paragraph6          0.000000  0.032787    0.016393    0.065574    0.016393
#
# TransitionTarget  Paragraph5  Paragraph6
# TransitionSource
# Paragraph4          0.027778    0.027778
# Text_Area           0.185185    0.098765
# Paragraph1          0.066667    0.000000
# Formula             0.030303    0.030303
# Paragraph3          0.225806    0.032258
# Paragraph2          0.000000    0.000000
# Figure              0.000000    0.080460
# SubFigure2          0.029703    0.019802
# SubFigure1          0.012346    0.000000
# SubFigure3          0.000000    0.048780
# Paragraph5          0.229167    0.145833
# Paragraph6          0.114754    0.524590

# %%
# Export transitionMatrix as CSV
transitionMatrixNormalized.to_csv("data/transitionMatrixNormalized-MarkovModel.csv")

# %%
#----------------------------------------------------------------------------------------
#
# 1.2 Identify transitions (with no self-transitions)
#
#----------------------------------------------------------------------------------------

# %%
# drop consecutive duplicate VisitedAOIs
dataNoConsDupVisits = data[['VisitedAOI']]     
dataNoConsDupVisits = data[(dataNoConsDupVisits.ne(dataNoConsDupVisits.shift())).any(axis=1)]

# %%
#identify transitions
noSelfTransitions = pd.DataFrame()
noSelfTransitions[['Respondent','TransitionSource','TransitionTarget']] = dataNoConsDupVisits.apply(lambda x: utils.identifyTransition(dataNoConsDupVisits,x.name), axis=1)

# %%
# Preview noSelfTransitions dataframe
noSelfTransitions.head()
# Out:
#                   Respondent TransitionSource TransitionTarget
# 0  Anonymous 14-11-22 09h35m       Paragraph4        Text_Area
# 1  Anonymous 14-11-22 09h35m        Text_Area       Paragraph1
# 2  Anonymous 14-11-22 09h35m       Paragraph1        Text_Area
# 4  Anonymous 14-11-22 09h35m          Formula       Paragraph1
# 5  Anonymous 14-11-22 09h35m       Paragraph1        Text_Area

# %%
# Generate transition matrix
noSelfTransitionsMatrix = utils.generateTransitionMatrix(noSelfTransitions,'TransitionSource','TransitionTarget')

# %%
# Display noSelfTransitionsMatrix
display(noSelfTransitionsMatrix)
# Out:
# TransitionTarget  Paragraph4  Text_Area  Paragraph1  Formula  Paragraph3  \
# TransitionSource
# Paragraph4                 0          5           0        4           3
# Text_Area                  4          0          10        2           9
# Paragraph1                 0          9           0        0           4
# Formula                    1          1           1        0           0
# Paragraph3                 2          0           4        1           0
# Paragraph2                 5         11           4        1           1
# Figure                     1         13           0        8           0
# SubFigure2                 0          5           1        1           0
# SubFigure1                 1          7           0        4           0
# SubFigure3                 1          1           0        2           0
# Paragraph5                 4          5           0        1           4
# Paragraph6                 1          9           1        0           0
#
# TransitionTarget  Paragraph2  Figure  SubFigure2  SubFigure1  SubFigure3  \
# TransitionSource
# Paragraph4                 5       2           1           3           0
# Text_Area                 10       5           2           7           0
# Paragraph1                 7       0           0           0           0
# Formula                    4       6           1           8           2
# Paragraph3                 2       0           1           3           0
# Paragraph2                 0       2           0           0           0
# Figure                     0       0          20          13           6
# SubFigure2                 2      20           0          21          20
# SubFigure1                 0      25          18           0           3
# SubFigure3                 0       5          20           1           0
# Paragraph5                 0       5           7           0           0
# Paragraph6                 0       1           1           3           1
#
# TransitionTarget  Paragraph5  Paragraph6
# TransitionSource
# Paragraph4                 1           0
# Text_Area                 14           7
# Paragraph1                 2           0
# Formula                    1           0
# Paragraph3                 6           1
# Paragraph2                 0           0
# Figure                     0           7
# SubFigure2                 3           2
# SubFigure1                 1           0
# SubFigure3                 0           1
# Paragraph5                 0           6
# Paragraph6                 6           0

# %%
# Export noSelfTransitions as CSV
noSelfTransitionsMatrix.to_csv("data/noSelfTransitions.csv")

# %%
#----------------------------------------------------------------------------------------
# Markov Model
#----------------------------------------------------------------------------------------

# %%
# Generate a transition matrix with values normalized over each row (by dividing all values by the sum of values in row)
noSelfTransitionsMatrixNormalized = utils.generateTransitionMatrix(noSelfTransitions,'TransitionSource','TransitionTarget',normalize='index')

# %%
# Display noSelfTransitionsMatrixNormalized
display(noSelfTransitionsMatrixNormalized)
# Out:
# TransitionTarget  Paragraph4  Text_Area  Paragraph1   Formula  Paragraph3  \
# TransitionSource
# Paragraph4          0.000000   0.208333    0.000000  0.166667    0.125000
# Text_Area           0.057143   0.000000    0.142857  0.028571    0.128571
# Paragraph1          0.000000   0.409091    0.000000  0.000000    0.181818
# Formula             0.040000   0.040000    0.040000  0.000000    0.000000
# Paragraph3          0.100000   0.000000    0.200000  0.050000    0.000000
# Paragraph2          0.208333   0.458333    0.166667  0.041667    0.041667
# Figure              0.014706   0.191176    0.000000  0.117647    0.000000
# SubFigure2          0.000000   0.066667    0.013333  0.013333    0.000000
# SubFigure1          0.016949   0.118644    0.000000  0.067797    0.000000
# SubFigure3          0.032258   0.032258    0.000000  0.064516    0.000000
# Paragraph5          0.125000   0.156250    0.000000  0.031250    0.125000
# Paragraph6          0.043478   0.391304    0.043478  0.000000    0.000000
#
# TransitionTarget  Paragraph2    Figure  SubFigure2  SubFigure1  SubFigure3  \
# TransitionSource
# Paragraph4          0.208333  0.083333    0.041667    0.125000    0.000000
# Text_Area           0.142857  0.071429    0.028571    0.100000    0.000000
# Paragraph1          0.318182  0.000000    0.000000    0.000000    0.000000
# Formula             0.160000  0.240000    0.040000    0.320000    0.080000
# Paragraph3          0.100000  0.000000    0.050000    0.150000    0.000000
# Paragraph2          0.000000  0.083333    0.000000    0.000000    0.000000
# Figure              0.000000  0.000000    0.294118    0.191176    0.088235
# SubFigure2          0.026667  0.266667    0.000000    0.280000    0.266667
# SubFigure1          0.000000  0.423729    0.305085    0.000000    0.050847
# SubFigure3          0.000000  0.161290    0.645161    0.032258    0.000000
# Paragraph5          0.000000  0.156250    0.218750    0.000000    0.000000
# Paragraph6          0.000000  0.043478    0.043478    0.130435    0.043478
#
# TransitionTarget  Paragraph5  Paragraph6
# TransitionSource
# Paragraph4          0.041667    0.000000
# Text_Area           0.200000    0.100000
# Paragraph1          0.090909    0.000000
# Formula             0.040000    0.000000
# Paragraph3          0.300000    0.050000
# Paragraph2          0.000000    0.000000
# Figure              0.000000    0.102941
# SubFigure2          0.040000    0.026667
# SubFigure1          0.016949    0.000000
# SubFigure3          0.000000    0.032258
# Paragraph5          0.000000    0.187500
# Paragraph6          0.260870    0.000000

# %%
# Export noSelfTransitionsMatrixNormalized as CSV
noSelfTransitionsMatrixNormalized.to_csv("data/noSelfTransitionsNormalized--MarkovModel.csv")
